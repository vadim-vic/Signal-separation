# %%
# An example for the import a .py file with functions to Google Colab from the Google Disk

# %%
# It requires the utility.py file, that contains the lines:
# import numpy as np
# Set of utility functions
# def u_test(x,y):
#    # This functions needs external tests and usage examples
#    # These tests are unit-tests and statistical tests
#    z = x + y
#    return z

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.insert(0,'/content/drive/MyDrive/AlohaCollisionDetector')
# download the files to the folder, namely utils.py
# and import desired functions from it
# Out:
# Mounted at /content/drive

# %%
# %ls
# %ls /content/drive/MyDrive/AlohaCollisionDetector/
# Out:
# drive/  sample_data/
#  10_RBFKernelTrick.ipynb
#  11_Plot_Birthday_Probability_NQ.ipynb
#  1_ViewData.ipynb
#  2_MixtureData.ipynb
#  3_MakeDataSet.ipynb
#  4_SimpleClassifier.ipynb
#  5_SSAfeatures1series.ipynb
#  6_10_Example_GenerateIQdatabySineWave.ipynb
#  6_11_Example_PhaseDifference_byHilbert.ipynb
#  6_12_Example_LowPassFilter_Hilbert_Average.ipynb
#  6_14_Example_MinMaxClusrtering.ipynb
#  6_15_Example_Plot3D.ipynb
#  6_1_Example_FastICA.ipynb
#  6_1_Example_FFT-ICA-MixtureDetection.ipynb
#  6_3_Example_RescalingMovigAverages.ipynb
#  6_4_Example_RFIDCarrierReconstruction.ipynb
#  6_5_Example_SinDataFit.ipynb
#  6_6_Example_FFT.ipynb
#  6_7_Example_Wavelet.ipynb
#  6_8_Example_SVDforComplexValuedMatrix.ipynb
#  6_9_Example_PhaseLockedLoopDetection.ipynb
#  7_MixAndShow.ipynb
#  8_PipelineToFeatureCollection.ipynb
#  9_1_Semor_amplitude.ipynb
#  9_2_Example_check_consecutive_sum_complex.ipynb
#  9_3_Example_Semor_plase.ipynb
#  9_Distance_to_7bit.ipynb
# ...

# %%
import numpy as np # This utility works with the numpy variables
from example_utility import * # Import all funtions * from the file, icluding u_text

# %%
# Check if the needed funtion is imported
import types
# List functions
functions_list = [name for name, obj in globals().items() if isinstance(obj, types.FunctionType)]
print(functions_list)
# Out:
# ['u_test']

# %%
# Import the function from the file
x = np.array([1,2,3])
y = np.array([4,5,6])

# Use the function
print(u_test(x,y))
# Out:
# [5 7 9]
