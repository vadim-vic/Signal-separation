# %% [markdown]
# <a href="https://colab.research.google.com/github/vadim-vic/Signal-separation/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = [1,2]
#y = [3]

# %%
z = frozenset(set(x) | set(y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-cc4dd639112e> in <cell line: 0>()
#       1 #z = frozenset(set(x) | set(y))
# ----> 2 z = frozenset([x, y])
#
# TypeError: unhashable type: 'list'

# %%
print(z)
# Out:
# frozenset({1, 2, 3})

# %%
database = {
    1: {"name": "Alice", "age": 25, "city": "New York"},
    2: {"name": "Bob", "age": 30, "city": "Los Angeles"},
    3: {"name": "Charlie", "age": 28, "city": "Chicago"},
}

# Access a user by ID (Fast O(1) lookup)
print(database[2]["name"])  # Bob

# Add a new user
database[4] = {"name": "David", "age": 22, "city": "Boston"}

# Update Bob's age
database[2]["age"] = 31

# Delete a user
del database[3]  # Remove Charlie

print(database)
# Out:
# Bob
# {1: {'name': 'Alice', 'age': 25, 'city': 'New York'}, 2: {'name': 'Bob', 'age': 31, 'city': 'Los Angeles'}, 4: {'name': 'David', 'age': 22, 'city': 'Boston'}}

# %%
print(database[2]['name'])
# Out:
# Bob

# %%
import numpy as np

# %%
# mdl_new.update({idx_new: {'err': err_min, 'sft': best_shift, 'par': best_b}})
mdl = {frozenset(): {'err': np.inf,
                     'sft': list([]),
                     'par': np.empty([])}}

# %%
for idx in range(500):
  err_min = np.random.normal(0,1)
  mdl.update({idx: {'err': err_min, 'sft': 0, 'par': 0}})
print(len(mdl))
# Out:
# 501

# %%
mdl = {
    1: {'err': 0.2, 'sft': 3, 'par': 1},
    2: {'err': 0.05, 'sft': 1, 'par': 2},
    3: {'err': 0.1, 'sft': 2, 'par': 3},
    4: {'err': 0.07, 'sft': 0, 'par': 4},
}

N = 7  # Number of records to store

# Sort by 'err' and keep the first N records
sorted_mdl = dict(sorted(mdl.items(), key=lambda x: x[1]['err'])[:N])

print(sorted_mdl)
# Out:
# {2: {'err': 0.05, 'sft': 1, 'par': 2}, 4: {'err': 0.07, 'sft': 0, 'par': 4}, 3: {'err': 0.1, 'sft': 2, 'par': 3}, 1: {'err': 0.2, 'sft': 3, 'par': 1}}

# %%
x = [1,3,5]
print(str(x))
# Out:
# [1, 3, 5]

# %%
x = {1,2,3}
cnt = 0

try:
  for i in x:
    x.add(i+1)
    cnt += 1
    if cnt > 10:
      break
    print(i)
except Exception as e:
  print('Noooo!:', e)
# Out:
# 1
# 2
# 3
# Noooo!: Set changed size during iteration

# %%
import matplotlib.pyplot as plt
# Data points (x, y)
data = [
    (0.020274, -4.899), (0.039335, -4.798), (0.055203, -4.697), (0.066135, -4.596),
    (0.070806, -4.4949), (0.068459, -4.3939), (0.059004, -4.2929), (0.043059, -4.1919),
    (0.021921, -4.0909), (-0.0025312, -3.9899), (-0.027995, -3.8889), (-0.051946, -3.7879),
    (-0.071881, -3.6869), (-0.085558, -3.5859), (-0.091238, -3.4848), (-0.087873, -3.3838),
    (-0.075257, -3.2828), (-0.054086, -3.1818), (-0.025949, -3.0808), (0.0067751, -2.9798),
    (0.041095, -2.8788), (0.073658, -2.7778), (0.10105, -2.6768), (0.1201, -2.5758),
    (0.12822, -2.4747), (0.12368, -2.3737), (0.10585, -2.2727), (0.07529, -2.1717),
